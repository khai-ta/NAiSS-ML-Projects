# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="white", color_codes=True)

# %%
path="/content/drive/MyDrive/Dataset/Iris.csv"
iris = pd.read_csv(path)
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **Scatter Plot**

# %%
sns.FacetGrid(iris, hue="Species", height=6).map(plt.scatter, "PetalLengthCm", "SepalWidthCm").add_legend()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-731e1798f91b> in <cell line: 1>()
# ----> 1 sns.FacetGrid(iris, hue="Species", height=6).map(plt.scatter, "PetalLengthCm", "SepalWidthCm").add_legend()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     735
#     736             # Decide what color to plot with
# --> 737             kwargs["color"] = self._facet_color(hue_k, kw_color)
#     738
#     739             # Insert the other hue aesthetics if appropriate
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in _facet_color(self, hue_index, kw_color)
#     836     def _facet_color(self, hue_index, kw_color):
#     837
# --> 838         color = self._colors[hue_index]
#     839         if kw_color is not None:
#     840             return kw_color
#
# IndexError: list index out of range

# %% [markdown]
# **Logistic Regression**

# %%
flower_mapping = {"setosa": 0, 'versicolor': 1, 'virginica': 2}
iris["Species"] = iris["Species"].map(flower_mapping)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2      NaN
# 1   2            4.9           3.0            1.4           0.2      NaN
# 2   3            4.7           3.2            1.3           0.2      NaN
# 3   4            4.6           3.1            1.5           0.2      NaN
# 4   5            5.0           3.6            1.4           0.2      NaN

# %%
x=iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
y=iris['Species'].values

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-cecb4634e72d> in <cell line: 1>()
# ----> 1 model.fit(x,y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1221             _dtype = [np.float64, np.float32]
#    1222
# -> 1223         X, y = self._validate_data(
#    1224             X,
#    1225             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1316     )
#    1317
# -> 1318     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1319
#    1320     check_consistent_length(X, y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _check_y(y, multi_output, y_numeric, estimator)
#    1338         estimator_name = _check_estimator_name(estimator)
#    1339         y = column_or_1d(y, warn=True)
# -> 1340         _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#    1341         _ensure_no_complex_data(y)
#    1342     if y_numeric and hasattr(y.dtype, "kind") and y.dtype.kind == "O":
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121         return
#     122
# --> 123     _assert_all_finite_element_wise(
#     124         X,
#     125         xp=xp,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     170                 "#estimators-that-handle-nan-values"
#     171             )
# --> 172         raise ValueError(msg_err)
#     173
#     174
#
# ValueError: Input y contains NaN.

# %%
model.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-27-7ad9b281eeba> in <cell line: 1>()
# ----> 1 model.score(x,y)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     762         from .metrics import accuracy_score
#     763
# --> 764         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     765
#     766     def _more_tags(self):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     380         """
#     381         xp, _ = get_namespace(X)
# --> 382         scores = self.decision_function(X)
#     383         if len(scores.shape) == 1:
#     384             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     358             this class would be predicted.
#     359         """
# --> 360         check_is_fitted(self)
#     361         xp, _ = get_namespace(X)
#     362
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1659
#    1660     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1662
#    1663
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
expected = y
predicted = model.predict(x)
predicted
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-29-f18b5a93fe70> in <cell line: 2>()
#       1 expected = y
# ----> 2 predicted = model.predict(x)
#       3 predicted
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     380         """
#     381         xp, _ = get_namespace(X)
# --> 382         scores = self.decision_function(X)
#     383         if len(scores.shape) == 1:
#     384             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     358             this class would be predicted.
#     359         """
# --> 360         check_is_fitted(self)
#     361         xp, _ = get_namespace(X)
#     362
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1659
#    1660     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1662
#    1663
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn import metrics

# %%
print(metrics.classification_report(expected, predicted))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b0508da2fe07> in <cell line: 1>()
# ----> 1 print(metrics.classification_report(expected, predicted))
#
# NameError: name 'predicted' is not defined

# %%
print(metrics.confusion_matrix(expected, predicted))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9ea14237ea65> in <cell line: 1>()
# ----> 1 print(metrics.confusion_matrix(expected, predicted))
#
# NameError: name 'predicted' is not defined
